# %% [markdown]
# # Sphere Class Tutorial

# %%
from axiomathbf import Sphere
from sympy import *

# %%
x, y, z = symbols("x y z")

# %% [markdown]
# ## Default Sphere

# %%
sphere1 = Sphere()
display(sphere1.getEquation())
# Out:
# x**2 + y**2 + z**2 - 1

# %%
print("Center: {}".format(sphere1.getCenter()))
print("Radius: {}".format(sphere1.getRadius()))
# Out:
# Center: Point3D(0, 0, 0)
# Radius: 1

# %%
print("Equation: {}".format(sphere1))
# Out:
# Equation: x**2 + y**2 + z**2 - 1

# %%
sphere1.draw()

# %% [markdown]
# ## Sphere from Equation

# %%
eq = 2*x**2+2*y**2+6*x-8*y+12
eq
# Out:
# 2*x**2 + 6*x + 2*y**2 - 8*y + 12

# %%
sphere2 = Sphere(eq=eq)

# %%
print(sphere2)
# Out:
# z**2 + (x + 3/2)**2 + (y - 2)**2 + 1/4

# %%
print("Center: {}".format(sphere2.getCenter()))
print("Radius: {}".format(sphere2.getRadius()))
# Out:
# Center: Point3D(-3/2, 2, 0)
# Radius: 1/2

# %%
sphere2.draw()

# %% [markdown]
# ## Sphere from Center and Radius
